# %%
# -*- coding: utf-8 -*-
from __future__ import division, print_function
from keras.models import Sequential
from keras.layers.core import Activation, Dense, Flatten
from keras.layers.convolutional import Conv2D
from keras.optimizers import Adam

from scipy.misc import imresize
#from scipy import misc

import collections
import numpy as np
import os

import wrapped_game
# Out:
# Using TensorFlow backend.

# %%
def preprocess_images(images):
    if images.shape[0] < 4:
        # single image
        x_t = images[0]
        x_t = imresize(x_t, (80, 80))
        x_t = x_t.astype("float")
        x_t /= 255.0
        s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    else:
        # 4 images
        xt_list = []
        for i in range(images.shape[0]):
            x_t = imresize(images[i], (80, 80))
            x_t = x_t.astype("float")
            x_t /= 255.0
            xt_list.append(x_t)
        s_t = np.stack((xt_list[0], xt_list[1], xt_list[2], xt_list[3]), axis=2)
    s_t = np.expand_dims(s_t, axis=0)
    return s_t

# %%
# experience : (s_tm1, a_t, r_t, s_t, game_over)
def get_next_batch(experience, model, num_actions, gamma, batch_size):
    
    batch_indices = np.random.randint(low=0, high=len(experience), size=batch_size)
    
    batch = [experience[i] for i in batch_indices]
    
    X = np.zeros((batch_size, 80, 80, 4))
    Y = np.zeros((batch_size, num_actions))
    
    for i in range(len(batch)):
        s_t, a_t, r_t, s_tp1, game_over = batch[i]
        X[i] = s_t
        Y[i] = model.predict(s_t)[0]
        Q_sa = np.max(model.predict(s_tp1)[0])
    
        if game_over:
            Y[i, a_t] = r_t
        else:
            Y[i, a_t] = r_t + gamma * Q_sa
    
    return X, Y

# %%
# initialize parameters
DATA_DIR = "." #"../data"
NUM_ACTIONS = 3 # number of valid actions (left, stay, right)
GAMMA = 0.99 # decay rate of past observations
INITIAL_EPSILON = 0.1 # starting value of epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
MEMORY_SIZE = 50000 # number of previous transitions to remember
NUM_EPOCHS_OBSERVE = 100
NUM_EPOCHS_TRAIN = 2000

BATCH_SIZE = 32
NUM_EPOCHS = NUM_EPOCHS_OBSERVE + NUM_EPOCHS_TRAIN

# %%
# build the model
model = Sequential()
model.add(Conv2D(32, kernel_size=8, strides=4, kernel_initializer="normal", padding="same", input_shape=(80, 80, 4)))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=4, strides=2, kernel_initializer="normal", padding="same"))
model.add(Activation("relu"))
model.add(Conv2D(64, kernel_size=3, strides=1, kernel_initializer="normal", padding="same"))
model.add(Activation("relu"))
model.add(Flatten())
model.add(Dense(512, kernel_initializer="normal"))
model.add(Activation("relu"))
model.add(Dense(3, kernel_initializer="normal"))

model.compile(optimizer=Adam(lr=1e-6), loss="mse")

# %%
# train network
game = wrapped_game.MyWrappedGame()
experience = collections.deque(maxlen=MEMORY_SIZE)

fout = open(os.path.join(DATA_DIR, "rl-network-results2.tsv"), "wb")
num_games, num_wins = 0, 0
epsilon = INITIAL_EPSILON

# %%
for e in range(NUM_EPOCHS):
    
    loss = 0.0
    
    # reset
    game.reset()
    
    # get first state
    a_0 = 1  # (0 = left, 1 = stay, 2 = right)
    
    # x_t:frame, r_0:reward, game_over
    x_t, r_0, game_over = game.step(a_0)

    # 欠損補間、リサイズ、floatキャスト
    # x_t : (1, 400, 400)
    # s_t : (1,  80,  80, 4)
    s_t = preprocess_images(x_t)
    
    while not game_over:
        
        # ■状態をキャッシュする : ４フレーム分の画像（1, 80, 80, 4）
        s_tm1 = s_t
        
        # ■アクションを決定
        if e <= NUM_EPOCHS_OBSERVE:
            a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0] # highは含まない
        else:
            # exploration/exploitation
            
            # exploration（探検）
            if np.random.rand() <= epsilon:
                a_t = np.random.randint(low=0, high=NUM_ACTIONS, size=1)[0] # highは含まない
            else: # exploitation（活用）
                
                # DNNに入れる
                q = model.predict(s_t)[0]
#                 print('q.shape:' + str(q.shape))
#                 print('q      :' + str(q))

                # action化する（インデックス化）
                a_t = np.argmax(q)
                #print(a_t)
        
        
        # ■アクションの実行、状態、報酬の取得 apply action, get reward 
        # ゲームオーバーとともにリワードは設定される（－１または１）、ゲームオーバー以外の場合は０
        x_t, r_t, game_over = game.step(a_t)
        #print(r_t)
        s_t = preprocess_images(x_t)
        
        
        # if reward, increment num_wins
        if r_t == 1:
            num_wins += 1
        
        # store experience
        experience.append((s_tm1, a_t, r_t, s_t, game_over))
        
        if e > NUM_EPOCHS_OBSERVE:
            # finished observing, now start training
            # get next batch
            X, Y = get_next_batch(experience, model, NUM_ACTIONS, GAMMA, BATCH_SIZE)
            loss += model.train_on_batch(X, Y)
        
    # reduce epsilon gradually
    if epsilon > FINAL_EPSILON:
        epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / NUM_EPOCHS
        
    print("Epoch {:04d}/{:d} | Loss {:.5f} | Win Count: {:d}".format(e + 1, NUM_EPOCHS, loss, num_wins))
    fout.write(bytes("{:04d}\t{:.5f}\t{:d}\n".format(e + 1, loss, num_wins).encode('utf-8')))

    if e % 100 == 0:
        model.save(os.path.join(DATA_DIR, "rl-network2.h5"), overwrite=True)
# Out:
# Epoch 0001/2100 | Loss 0.00000 | Win Count: 0
# Epoch 0002/2100 | Loss 0.00000 | Win Count: 0
# Epoch 0003/2100 | Loss 0.00000 | Win Count: 0
# Epoch 0004/2100 | Loss 0.00000 | Win Count: 0
# Epoch 0005/2100 | Loss 0.00000 | Win Count: 0
# Epoch 0006/2100 | Loss 0.00000 | Win Count: 0
# Epoch 0007/2100 | Loss 0.00000 | Win Count: 0
# Epoch 0008/2100 | Loss 0.00000 | Win Count: 1
# Epoch 0009/2100 | Loss 0.00000 | Win Count: 1
# Epoch 0010/2100 | Loss 0.00000 | Win Count: 2
# Epoch 0011/2100 | Loss 0.00000 | Win Count: 2
# Epoch 0012/2100 | Loss 0.00000 | Win Count: 2
# Epoch 0013/2100 | Loss 0.00000 | Win Count: 2
# Epoch 0014/2100 | Loss 0.00000 | Win Count: 3
# Epoch 0015/2100 | Loss 0.00000 | Win Count: 3
# Epoch 0016/2100 | Loss 0.00000 | Win Count: 3
# Epoch 0017/2100 | Loss 0.00000 | Win Count: 3
# Epoch 0018/2100 | Loss 0.00000 | Win Count: 4
# Epoch 0019/2100 | Loss 0.00000 | Win Count: 4
# Epoch 0020/2100 | Loss 0.00000 | Win Count: 5
# Epoch 0021/2100 | Loss 0.00000 | Win Count: 5
# Epoch 0022/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0023/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0024/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0025/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0026/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0027/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0028/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0029/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0030/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0031/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0032/2100 | Loss 0.00000 | Win Count: 6
# Epoch 0033/2100 | Loss 0.00000 | Win Count: 7
# Epoch 0034/2100 | Loss 0.00000 | Win Count: 7
# Epoch 0035/2100 | Loss 0.00000 | Win Count: 7
# Epoch 0036/2100 | Loss 0.00000 | Win Count: 8
# Epoch 0037/2100 | Loss 0.00000 | Win Count: 8
# Epoch 0038/2100 | Loss 0.00000 | Win Count: 8
# Epoch 0039/2100 | Loss 0.00000 | Win Count: 8
# Epoch 0040/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0041/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0042/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0043/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0044/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0045/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0046/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0047/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0048/2100 | Loss 0.00000 | Win Count: 9
# Epoch 0049/2100 | Loss 0.00000 | Win Count: 10
# Epoch 0050/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0051/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0052/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0053/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0054/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0055/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0056/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0057/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0058/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0059/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0060/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0061/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0062/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0063/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0064/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0065/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0066/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0067/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0068/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0069/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0070/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0071/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0072/2100 | Loss 0.00000 | Win Count: 11
# Epoch 0073/2100 | Loss 0.00000 | Win Count: 12
# Epoch 0074/2100 | Loss 0.00000 | Win Count: 12
# Epoch 0075/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0076/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0077/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0078/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0079/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0080/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0081/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0082/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0083/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0084/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0085/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0086/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0087/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0088/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0089/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0090/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0091/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0092/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0093/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0094/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0095/2100 | Loss 0.00000 | Win Count: 13
# Epoch 0096/2100 | Loss 0.00000 | Win Count: 14
# Epoch 0097/2100 | Loss 0.00000 | Win Count: 14
# Epoch 0098/2100 | Loss 0.00000 | Win Count: 14
# Epoch 0099/2100 | Loss 0.00000 | Win Count: 14
# Epoch 0100/2100 | Loss 0.00000 | Win Count: 14
# Epoch 0101/2100 | Loss 0.00000 | Win Count: 14
# Epoch 0102/2100 | Loss 0.41098 | Win Count: 14
# Epoch 0103/2100 | Loss 0.37042 | Win Count: 15
# Epoch 0104/2100 | Loss 0.46307 | Win Count: 15
# Epoch 0105/2100 | Loss 0.50821 | Win Count: 15
# Epoch 0106/2100 | Loss 0.38918 | Win Count: 15
# Epoch 0107/2100 | Loss 0.43743 | Win Count: 15
# Epoch 0108/2100 | Loss 0.51914 | Win Count: 15
# Epoch 0109/2100 | Loss 0.51082 | Win Count: 15
# Epoch 0110/2100 | Loss 0.27815 | Win Count: 16
# Epoch 0111/2100 | Loss 0.37788 | Win Count: 17
# Epoch 0112/2100 | Loss 0.38245 | Win Count: 17
# Epoch 0113/2100 | Loss 0.40785 | Win Count: 17
# Epoch 0114/2100 | Loss 0.34616 | Win Count: 17
# Epoch 0115/2100 | Loss 0.45137 | Win Count: 17
# Epoch 0116/2100 | Loss 0.39061 | Win Count: 17
# Epoch 0117/2100 | Loss 0.39389 | Win Count: 18
# Epoch 0118/2100 | Loss 0.41868 | Win Count: 18
# Epoch 0119/2100 | Loss 0.41746 | Win Count: 18
# Epoch 0120/2100 | Loss 0.33135 | Win Count: 18
# Epoch 0121/2100 | Loss 0.37102 | Win Count: 18
# Epoch 0122/2100 | Loss 0.42854 | Win Count: 19
# Epoch 0123/2100 | Loss 0.39315 | Win Count: 19
# Epoch 0124/2100 | Loss 0.45487 | Win Count: 19
# Epoch 0125/2100 | Loss 0.51220 | Win Count: 19
# Epoch 0126/2100 | Loss 0.37490 | Win Count: 19
# Epoch 0127/2100 | Loss 0.41301 | Win Count: 19
# Epoch 0128/2100 | Loss 0.39947 | Win Count: 19
# Epoch 0129/2100 | Loss 0.39650 | Win Count: 19
# Epoch 0130/2100 | Loss 0.28655 | Win Count: 19
# Epoch 0131/2100 | Loss 0.41025 | Win Count: 19
# Epoch 0132/2100 | Loss 0.37116 | Win Count: 19
# Epoch 0133/2100 | Loss 0.30023 | Win Count: 19
# Epoch 0134/2100 | Loss 0.53054 | Win Count: 19
# Epoch 0135/2100 | Loss 0.48431 | Win Count: 19
# Epoch 0136/2100 | Loss 0.30728 | Win Count: 20
# Epoch 0137/2100 | Loss 0.32033 | Win Count: 21
# Epoch 0138/2100 | Loss 0.35055 | Win Count: 21
# Epoch 0139/2100 | Loss 0.34927 | Win Count: 21
# Epoch 0140/2100 | Loss 0.30449 | Win Count: 22
# Epoch 0141/2100 | Loss 0.29688 | Win Count: 22
# Epoch 0142/2100 | Loss 0.47899 | Win Count: 22
# Epoch 0143/2100 | Loss 0.42425 | Win Count: 22
# Epoch 0144/2100 | Loss 0.38363 | Win Count: 22
# Epoch 0145/2100 | Loss 0.36526 | Win Count: 22
# Epoch 0146/2100 | Loss 0.36177 | Win Count: 22
# Epoch 0147/2100 | Loss 0.32672 | Win Count: 22
# Epoch 0148/2100 | Loss 0.44166 | Win Count: 22
# Epoch 0149/2100 | Loss 0.42049 | Win Count: 22
# Epoch 0150/2100 | Loss 0.29549 | Win Count: 22
# Epoch 0151/2100 | Loss 0.38901 | Win Count: 22
# Epoch 0152/2100 | Loss 0.28156 | Win Count: 23
# Epoch 0153/2100 | Loss 0.40208 | Win Count: 23
# Epoch 0154/2100 | Loss 0.40848 | Win Count: 23
# Epoch 0155/2100 | Loss 0.26634 | Win Count: 23
# Epoch 0156/2100 | Loss 0.39546 | Win Count: 23
# Epoch 0157/2100 | Loss 0.35407 | Win Count: 23
# Epoch 0158/2100 | Loss 0.42204 | Win Count: 23
# Epoch 0159/2100 | Loss 0.31255 | Win Count: 23
# Epoch 0160/2100 | Loss 0.33969 | Win Count: 23
# Epoch 0161/2100 | Loss 0.36185 | Win Count: 23
# Epoch 0162/2100 | Loss 0.43517 | Win Count: 24
# Epoch 0163/2100 | Loss 0.28513 | Win Count: 24
# Epoch 0164/2100 | Loss 0.44485 | Win Count: 24
# Epoch 0165/2100 | Loss 0.32349 | Win Count: 24
# Epoch 0166/2100 | Loss 0.43230 | Win Count: 24
# Epoch 0167/2100 | Loss 0.40510 | Win Count: 24
# Epoch 0168/2100 | Loss 0.33683 | Win Count: 24
# Epoch 0169/2100 | Loss 0.38674 | Win Count: 24
# Epoch 0170/2100 | Loss 0.25247 | Win Count: 24
# Epoch 0171/2100 | Loss 0.26837 | Win Count: 24
# Epoch 0172/2100 | Loss 0.41485 | Win Count: 24
# Epoch 0173/2100 | Loss 0.31975 | Win Count: 24
# Epoch 0174/2100 | Loss 0.45861 | Win Count: 24
# Epoch 0175/2100 | Loss 0.35875 | Win Count: 24
# Epoch 0176/2100 | Loss 0.42529 | Win Count: 25
# Epoch 0177/2100 | Loss 0.37603 | Win Count: 25
# Epoch 0178/2100 | Loss 0.28875 | Win Count: 26
# Epoch 0179/2100 | Loss 0.37455 | Win Count: 26
# Epoch 0180/2100 | Loss 0.24286 | Win Count: 26
# Epoch 0181/2100 | Loss 0.36060 | Win Count: 26
# Epoch 0182/2100 | Loss 0.36136 | Win Count: 26
# Epoch 0183/2100 | Loss 0.46239 | Win Count: 26
# Epoch 0184/2100 | Loss 0.32686 | Win Count: 26
# Epoch 0185/2100 | Loss 0.36616 | Win Count: 26
# Epoch 0186/2100 | Loss 0.53435 | Win Count: 26
# Epoch 0187/2100 | Loss 0.32727 | Win Count: 26
# Epoch 0188/2100 | Loss 0.35175 | Win Count: 27
# Epoch 0189/2100 | Loss 0.30908 | Win Count: 27
# Epoch 0190/2100 | Loss 0.31315 | Win Count: 27
# Epoch 0191/2100 | Loss 0.30380 | Win Count: 27
# Epoch 0192/2100 | Loss 0.34454 | Win Count: 27
# Epoch 0193/2100 | Loss 0.31691 | Win Count: 27
# Epoch 0194/2100 | Loss 0.30042 | Win Count: 27
# Epoch 0195/2100 | Loss 0.34462 | Win Count: 28
# Epoch 0196/2100 | Loss 0.38740 | Win Count: 28
# Epoch 0197/2100 | Loss 0.33269 | Win Count: 28
# Epoch 0198/2100 | Loss 0.31021 | Win Count: 28
# Epoch 0199/2100 | Loss 0.46800 | Win Count: 28
# Epoch 0200/2100 | Loss 0.26120 | Win Count: 29
# Epoch 0201/2100 | Loss 0.35063 | Win Count: 29
# Epoch 0202/2100 | Loss 0.45677 | Win Count: 29
# Epoch 0203/2100 | Loss 0.37720 | Win Count: 29
# Epoch 0204/2100 | Loss 0.41576 | Win Count: 29
# Epoch 0205/2100 | Loss 0.38623 | Win Count: 29
# Epoch 0206/2100 | Loss 0.35053 | Win Count: 29
# Epoch 0207/2100 | Loss 0.30444 | Win Count: 29
# Epoch 0208/2100 | Loss 0.39502 | Win Count: 29
# Epoch 0209/2100 | Loss 0.34182 | Win Count: 29
# Epoch 0210/2100 | Loss 0.39530 | Win Count: 29
# Epoch 0211/2100 | Loss 0.26070 | Win Count: 29
# Epoch 0212/2100 | Loss 0.33821 | Win Count: 29
# Epoch 0213/2100 | Loss 0.34575 | Win Count: 29
# Epoch 0214/2100 | Loss 0.23769 | Win Count: 29
# Epoch 0215/2100 | Loss 0.41648 | Win Count: 29
# Epoch 0216/2100 | Loss 0.31875 | Win Count: 30
# Epoch 0217/2100 | Loss 0.23370 | Win Count: 30
# Epoch 0218/2100 | Loss 0.39865 | Win Count: 30
# Epoch 0219/2100 | Loss 0.36674 | Win Count: 30
# Epoch 0220/2100 | Loss 0.32266 | Win Count: 30
# Epoch 0221/2100 | Loss 0.24865 | Win Count: 30
# Epoch 0222/2100 | Loss 0.31687 | Win Count: 30
# Epoch 0223/2100 | Loss 0.41772 | Win Count: 30
# Epoch 0224/2100 | Loss 0.27012 | Win Count: 30
# Epoch 0225/2100 | Loss 0.25081 | Win Count: 30
# Epoch 0226/2100 | Loss 0.33186 | Win Count: 30
# Epoch 0227/2100 | Loss 0.28367 | Win Count: 30
# Epoch 0228/2100 | Loss 0.31499 | Win Count: 30
# Epoch 0229/2100 | Loss 0.27421 | Win Count: 30
# Epoch 0230/2100 | Loss 0.28795 | Win Count: 30
# Epoch 0231/2100 | Loss 0.31334 | Win Count: 30
# Epoch 0232/2100 | Loss 0.30889 | Win Count: 30
# Epoch 0233/2100 | Loss 0.35404 | Win Count: 30
# Epoch 0234/2100 | Loss 0.32075 | Win Count: 30
# Epoch 0235/2100 | Loss 0.27494 | Win Count: 30
# Epoch 0236/2100 | Loss 0.29471 | Win Count: 30
# Epoch 0237/2100 | Loss 0.25417 | Win Count: 30
# Epoch 0238/2100 | Loss 0.33892 | Win Count: 30
# Epoch 0239/2100 | Loss 0.43081 | Win Count: 30
# Epoch 0240/2100 | Loss 0.30009 | Win Count: 30
# Epoch 0241/2100 | Loss 0.38644 | Win Count: 30
# Epoch 0242/2100 | Loss 0.33314 | Win Count: 31
# Epoch 0243/2100 | Loss 0.30508 | Win Count: 32
# Epoch 0244/2100 | Loss 0.31180 | Win Count: 32
# Epoch 0245/2100 | Loss 0.33270 | Win Count: 32
# Epoch 0246/2100 | Loss 0.28449 | Win Count: 32
# Epoch 0247/2100 | Loss 0.28607 | Win Count: 32
# Epoch 0248/2100 | Loss 0.32487 | Win Count: 33
# Epoch 0249/2100 | Loss 0.38839 | Win Count: 33
# Epoch 0250/2100 | Loss 0.33553 | Win Count: 33
# Epoch 0251/2100 | Loss 0.28347 | Win Count: 33
# Epoch 0252/2100 | Loss 0.28378 | Win Count: 33
# Epoch 0253/2100 | Loss 0.32795 | Win Count: 33
# Epoch 0254/2100 | Loss 0.32776 | Win Count: 33
# Epoch 0255/2100 | Loss 0.24972 | Win Count: 33
# Epoch 0256/2100 | Loss 0.30116 | Win Count: 33
# Epoch 0257/2100 | Loss 0.32750 | Win Count: 33
# Epoch 0258/2100 | Loss 0.34322 | Win Count: 33
# Epoch 0259/2100 | Loss 0.26904 | Win Count: 33
# Epoch 0260/2100 | Loss 0.28348 | Win Count: 34
# Epoch 0261/2100 | Loss 0.36398 | Win Count: 34
# Epoch 0262/2100 | Loss 0.33889 | Win Count: 34
# Epoch 0263/2100 | Loss 0.24471 | Win Count: 34
# Epoch 0264/2100 | Loss 0.37670 | Win Count: 34
# Epoch 0265/2100 | Loss 0.30070 | Win Count: 34
# Epoch 0266/2100 | Loss 0.28583 | Win Count: 35
# Epoch 0267/2100 | Loss 0.35241 | Win Count: 35
# Epoch 0268/2100 | Loss 0.28502 | Win Count: 35
# Epoch 0269/2100 | Loss 0.32307 | Win Count: 35
# Epoch 0270/2100 | Loss 0.31456 | Win Count: 35
# Epoch 0271/2100 | Loss 0.27097 | Win Count: 35
# Epoch 0272/2100 | Loss 0.31475 | Win Count: 35
# Epoch 0273/2100 | Loss 0.22505 | Win Count: 35
# Epoch 0274/2100 | Loss 0.21174 | Win Count: 35
# Epoch 0275/2100 | Loss 0.28332 | Win Count: 36
# Epoch 0276/2100 | Loss 0.34596 | Win Count: 37
# Epoch 0277/2100 | Loss 0.37141 | Win Count: 37
# Epoch 0278/2100 | Loss 0.28590 | Win Count: 37
# Epoch 0279/2100 | Loss 0.29700 | Win Count: 37
# Epoch 0280/2100 | Loss 0.28019 | Win Count: 38
# Epoch 0281/2100 | Loss 0.25080 | Win Count: 39
# Epoch 0282/2100 | Loss 0.34902 | Win Count: 39
# Epoch 0283/2100 | Loss 0.28523 | Win Count: 39
# Epoch 0284/2100 | Loss 0.25508 | Win Count: 40
# Epoch 0285/2100 | Loss 0.38998 | Win Count: 40
# Epoch 0286/2100 | Loss 0.27235 | Win Count: 40
# Epoch 0287/2100 | Loss 0.21260 | Win Count: 40
# Epoch 0288/2100 | Loss 0.24029 | Win Count: 40
# Epoch 0289/2100 | Loss 0.22782 | Win Count: 40
# Epoch 0290/2100 | Loss 0.28246 | Win Count: 40
# Epoch 0291/2100 | Loss 0.29526 | Win Count: 41
# Epoch 0292/2100 | Loss 0.24428 | Win Count: 41
# Epoch 0293/2100 | Loss 0.22618 | Win Count: 41
# Epoch 0294/2100 | Loss 0.24944 | Win Count: 41
# Epoch 0295/2100 | Loss 0.27827 | Win Count: 42
# Epoch 0296/2100 | Loss 0.32904 | Win Count: 42
# Epoch 0297/2100 | Loss 0.30062 | Win Count: 42
# Epoch 0298/2100 | Loss 0.27499 | Win Count: 42
# Epoch 0299/2100 | Loss 0.28376 | Win Count: 42
# Epoch 0300/2100 | Loss 0.27046 | Win Count: 43
# Epoch 0301/2100 | Loss 0.29308 | Win Count: 43
# Epoch 0302/2100 | Loss 0.24291 | Win Count: 43
# Epoch 0303/2100 | Loss 0.25854 | Win Count: 43
# Epoch 0304/2100 | Loss 0.22391 | Win Count: 43
# Epoch 0305/2100 | Loss 0.28014 | Win Count: 43
# Epoch 0306/2100 | Loss 0.26835 | Win Count: 43
# Epoch 0307/2100 | Loss 0.24955 | Win Count: 43
# Epoch 0308/2100 | Loss 0.26681 | Win Count: 43
# Epoch 0309/2100 | Loss 0.28096 | Win Count: 43
# Epoch 0310/2100 | Loss 0.20236 | Win Count: 43
# Epoch 0311/2100 | Loss 0.27247 | Win Count: 43
# Epoch 0312/2100 | Loss 0.32126 | Win Count: 43
# Epoch 0313/2100 | Loss 0.25867 | Win Count: 44
# Epoch 0314/2100 | Loss 0.23797 | Win Count: 44

# %%
fout.close()
model.save(os.path.join(DATA_DIR, "rl-network.h5"), overwrite=True)
